# %%
import csv
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# Explore the csv, featuring aid received, literacy rates, and GDP per capita. Clean the data. Many columns have ".." signalling that the data doesn't exist. This is particularly true of the literacy rates indicator, which, for many countries, does not record a statistic per year. For now, we'll replace those with zeroes.

# %%
country_aid_gdp_lit_df = pd.read_csv("data/2nd_try_aid_gdp_lit.csv")

# %%
#Reshape table so each year for each country is its own row. 
df1 = country_aid_gdp_lit_df.set_index(['Country Name', 'Series Name'])
df1.columns.name = 'year'
df1 = df1.stack().unstack('Series Name')

# %%
df1.head(3)
# Out:
# Series Name       GDP per capita (current US$)  \
# Country Name year
# Afghanistan  1990                           ..
#              1991                           ..
#              1992                           ..
#
# Series Name       Literacy rate, adult total (% of people ages 15 and above)  \
# Country Name year
# Afghanistan  1990                                                 ..
#              1991                                                 ..
#              1992                                                 ..
#
# Series Name       Net official development assistance and official aid received (current US$)
# Country Name year
# Afghanistan  1990                                          121720000
#              1991                                          507530000
#              1992                                          204900000

# %%
#replace ".." with zeros
df1 = df1.replace("..", "0")

# %%
df1.head(3)
# Out:
# Series Name       GDP per capita (current US$)  \
# Country Name year
# Afghanistan  1990                            0
#              1991                            0
#              1992                            0
#
# Series Name       Literacy rate, adult total (% of people ages 15 and above)  \
# Country Name year
# Afghanistan  1990                                                  0
#              1991                                                  0
#              1992                                                  0
#
# Series Name       Net official development assistance and official aid received (current US$)
# Country Name year
# Afghanistan  1990                                          121720000
#              1991                                          507530000
#              1992                                          204900000

# %%
#lets take a look at the dtypes
df1.dtypes
# Out:
# Series Name
# GDP per capita (current US$)                                                   object
# Literacy rate, adult total (% of people ages 15 and above)                     object
# Net official development assistance and official aid received (current US$)    object
# dtype: object

# %%
#all objects? Need to change that, also need to change column name
df1 = df1.reset_index()
df1.dtypes
# Out:
# Series Name
# Country Name                                                                   object
# year                                                                           object
# GDP per capita (current US$)                                                   object
# Literacy rate, adult total (% of people ages 15 and above)                     object
# Net official development assistance and official aid received (current US$)    object
# dtype: object

# %%
df1.index.names = ['id']
df1.columns = ['country', 'year', 'gdp_per_capita', 'literacy_rate', 'net_aid_received']

# %%
#time to change the column types
df1['country'] = df1['country'].astype('str')
df1['year'] = df1['year'].astype("int32")
df1['gdp_per_capita'] = df1['gdp_per_capita'].astype('float64')
df1['literacy_rate'] = df1['literacy_rate'].astype('float64')
df1['net_aid_received'] = df1['net_aid_received'].astype('float64')

# %%
df1.head(3)
# Out:
#         country  year  gdp_per_capita  literacy_rate  net_aid_received
# id
# 0   Afghanistan  1990             0.0            0.0       121720000.0
# 1   Afghanistan  1991             0.0            0.0       507530000.0
# 2   Afghanistan  1992             0.0            0.0       204900000.0

# %%
df1.dtypes
# Out:
# country              object
# year                  int32
# gdp_per_capita      float64
# literacy_rate       float64
# net_aid_received    float64
# dtype: object

# %%
df1.to_csv("clean_data/gdp_lit_aid.csv")

# %% [markdown]
# Now it's time to investigate aid spending per sector by year csv. Should not be as big as the previous csv. Move from wide to long.

# %%
df2 = pd.read_csv("data/aid_spending_by_sector_per_yer.csv")

# %%
df2.head(5)
# Out:
#                                        Sector(s)  Time Period     1990  \
# 0                          I.1. Education, Total          NaN  5664.71
# 1                             I.2. Health, Total          NaN  1613.27
# 2         I.5. Government & Civil Society, Total          NaN  1735.06
# 3  II. Economic Infrastructure & Services, Total          NaN  8382.07
# 4         II.5. Business & Other Services, Total          NaN   394.33
#
#        1991     1992     1993      1994      1995      1996      1997  \
# 0   4973.52  4793.35  4672.43   5376.85   6054.95   5261.22   4683.23
# 1   1424.84  1617.43  1654.98   1831.49   2171.42   2283.51   1667.18
# 2   1387.19  1717.47  1300.48   1425.16   1792.34   1496.31   1130.09
# 3  12182.65  8038.75  9591.39  10805.58  12880.17  11512.02  10127.12
# 4    308.94   430.42   346.42   1206.94    659.63    642.43   1008.88
#
#      ...         2007      2008      2009      2010      2011      2012  \
# 0    ...      8440.51   9417.38   9329.86   9318.94   9780.09   8793.18
# 1    ...      4447.27   5077.02   4990.22   5108.05   6012.12   6160.02
# 2    ...     11678.39  13221.55  13325.07  13983.96  14531.76  13014.89
# 3    ...     12242.26  19522.05  15348.72  19487.56  16998.42  17974.14
# 4    ...      1443.38   1631.89   1106.67   1309.79   1746.30    941.00
#
#        2013      2014      2015      2016
# 0   8227.74   9157.74   8050.54   8635.15
# 1   5938.76   5324.30   6094.47   6393.36
# 2  12526.83  12952.03  11936.95  11924.34
# 3  20836.01  22160.40  22234.71  22004.57
# 4   1245.62   2152.68   1238.58   1385.94
#
# [5 rows x 29 columns]

# %%
#lets drop the time period column and reshape the whole thing with years as rows
df2 = df2.drop(['Time Period'], axis=1)

# %%
df2 = df2.set_index(['Sector(s)'])

# %%
df2.head()
# Out:
#                                                   1990      1991     1992  \
# Sector(s)
# I.1. Education, Total                          5664.71   4973.52  4793.35
# I.2. Health, Total                             1613.27   1424.84  1617.43
# I.5. Government & Civil Society, Total         1735.06   1387.19  1717.47
# II. Economic Infrastructure & Services, Total  8382.07  12182.65  8038.75
# II.5. Business & Other Services, Total          394.33    308.94   430.42
#
#                                                   1993      1994      1995  \
# Sector(s)
# I.1. Education, Total                          4672.43   5376.85   6054.95
# I.2. Health, Total                             1654.98   1831.49   2171.42
# I.5. Government & Civil Society, Total         1300.48   1425.16   1792.34
# II. Economic Infrastructure & Services, Total  9591.39  10805.58  12880.17
# II.5. Business & Other Services, Total          346.42   1206.94    659.63
#
#                                                    1996      1997     1998  \
# Sector(s)
# I.1. Education, Total                           5261.22   4683.23  4492.27
# I.2. Health, Total                              2283.51   1667.18  1593.50
# I.5. Government & Civil Society, Total          1496.31   1130.09  1946.19
# II. Economic Infrastructure & Services, Total  11512.02  10127.12  7803.86
# II.5. Business & Other Services, Total           642.43   1008.88   534.92
#
#                                                   1999    ...         2007  \
# Sector(s)                                                 ...
# I.1. Education, Total                          5038.70    ...      8440.51
# I.2. Health, Total                             1973.92    ...      4447.27
# I.5. Government & Civil Society, Total         1997.61    ...     11678.39
# II. Economic Infrastructure & Services, Total  8062.73    ...     12242.26
# II.5. Business & Other Services, Total         1444.93    ...      1443.38
#
#                                                    2008      2009      2010  \
# Sector(s)
# I.1. Education, Total                           9417.38   9329.86   9318.94
# I.2. Health, Total                              5077.02   4990.22   5108.05
# I.5. Government & Civil Society, Total         13221.55  13325.07  13983.96
# II. Economic Infrastructure & Services, Total  19522.05  15348.72  19487.56
# II.5. Business & Other Services, Total          1631.89   1106.67   1309.79
#
#                                                    2011      2012      2013  \
# Sector(s)
# I.1. Education, Total                           9780.09   8793.18   8227.74
# I.2. Health, Total                              6012.12   6160.02   5938.76
# I.5. Government & Civil Society, Total         14531.76  13014.89  12526.83
# II. Economic Infrastructure & Services, Total  16998.42  17974.14  20836.01
# II.5. Business & Other Services, Total          1746.30    941.00   1245.62
#
#                                                    2014      2015      2016
# Sector(s)
# I.1. Education, Total                           9157.74   8050.54   8635.15
# I.2. Health, Total                              5324.30   6094.47   6393.36
# I.5. Government & Civil Society, Total         12952.03  11936.95  11924.34
# II. Economic Infrastructure & Services, Total  22160.40  22234.71  22004.57
# II.5. Business & Other Services, Total          2152.68   1238.58   1385.94
#
# [5 rows x 27 columns]

# %%
df2 = df2.T

# %%
df2.index.name = 'year'

# %%
df2 = df2.reset_index()

# %%
df2.head()
# Out:
# Sector(s)  year  I.1. Education, Total  I.2. Health, Total  \
# 0          1990                5664.71             1613.27
# 1          1991                4973.52             1424.84
# 2          1992                4793.35             1617.43
# 3          1993                4672.43             1654.98
# 4          1994                5376.85             1831.49
#
# Sector(s)  I.5. Government & Civil Society, Total  \
# 0                                         1735.06
# 1                                         1387.19
# 2                                         1717.47
# 3                                         1300.48
# 4                                         1425.16
#
# Sector(s)  II. Economic Infrastructure & Services, Total  \
# 0                                                8382.07
# 1                                               12182.65
# 2                                                8038.75
# 3                                                9591.39
# 4                                               10805.58
#
# Sector(s)  II.5. Business & Other Services, Total  \
# 0                                          394.33
# 1                                          308.94
# 2                                          430.42
# 3                                          346.42
# 4                                         1206.94
#
# Sector(s)  III. Production Sectors, Total  \
# 0                                 6878.85
# 1                                 6199.57
# 2                                 8069.91
# 3                                 5780.78
# 4                                 5265.10
#
# Sector(s)  IV. Multi-Sector / Cross-Cutting, Total
# 0                                          1871.51
# 1                                          1524.03
# 2                                          2041.24
# 3                                          2045.15
# 4                                          1965.18

# %%
df2.dtypes
# Out:
# Sector(s)
# year                                              object
# I.1. Education, Total                            float64
# I.2. Health, Total                               float64
# I.5. Government & Civil Society, Total           float64
# II. Economic Infrastructure & Services, Total    float64
# II.5. Business & Other Services, Total           float64
# III. Production Sectors, Total                   float64
# IV. Multi-Sector / Cross-Cutting, Total          float64
# dtype: object

# %%
df2.index.names = ["id"]
df2.head(3)
# Out:
# Sector(s)  year  I.1. Education, Total  I.2. Health, Total  \
# id
# 0          1990                5664.71             1613.27
# 1          1991                4973.52             1424.84
# 2          1992                4793.35             1617.43
#
# Sector(s)  I.5. Government & Civil Society, Total  \
# id
# 0                                         1735.06
# 1                                         1387.19
# 2                                         1717.47
#
# Sector(s)  II. Economic Infrastructure & Services, Total  \
# id
# 0                                                8382.07
# 1                                               12182.65
# 2                                                8038.75
#
# Sector(s)  II.5. Business & Other Services, Total  \
# id
# 0                                          394.33
# 1                                          308.94
# 2                                          430.42
#
# Sector(s)  III. Production Sectors, Total  \
# id
# 0                                 6878.85
# 1                                 6199.57
# 2                                 8069.91
#
# Sector(s)  IV. Multi-Sector / Cross-Cutting, Total
# id
# 0                                          1871.51
# 1                                          1524.03
# 2                                          2041.24

# %%
df2.dtypes
# Out:
# Sector(s)
# year                                              object
# I.1. Education, Total                            float64
# I.2. Health, Total                               float64
# I.5. Government & Civil Society, Total           float64
# II. Economic Infrastructure & Services, Total    float64
# II.5. Business & Other Services, Total           float64
# III. Production Sectors, Total                   float64
# IV. Multi-Sector / Cross-Cutting, Total          float64
# dtype: object

# %%
df2.shape
# Out:
# (27, 8)

# %%
df2.columns = ['year', 'education', 'health', 'government', 'economic', 'business', 'production', 'multi-sector']

# %%
df2['year'] = df2['year'].astype('int32')

# %%
df2.dtypes
# Out:
# year              int32
# education       float64
# health          float64
# government      float64
# economic        float64
# business        float64
# production      float64
# multi-sector    float64
# dtype: object

# %%
df2.head(3)
# Out:
#     year  education   health  government  economic  business  production  \
# id
# 0   1990    5664.71  1613.27     1735.06   8382.07    394.33     6878.85
# 1   1991    4973.52  1424.84     1387.19  12182.65    308.94     6199.57
# 2   1992    4793.35  1617.43     1717.47   8038.75    430.42     8069.91
#
#     multi-sector
# id
# 0        1871.51
# 1        1524.03
# 2        2041.24

# %%
df2 = df2.set_index(['year'])
df2.head()
# Out:
#       education   health  government  economic  business  production  \
# year
# 1990    5664.71  1613.27     1735.06   8382.07    394.33     6878.85
# 1991    4973.52  1424.84     1387.19  12182.65    308.94     6199.57
# 1992    4793.35  1617.43     1717.47   8038.75    430.42     8069.91
# 1993    4672.43  1654.98     1300.48   9591.39    346.42     5780.78
# 1994    5376.85  1831.49     1425.16  10805.58   1206.94     5265.10
#
#       multi-sector
# year
# 1990       1871.51
# 1991       1524.03
# 1992       2041.24
# 1993       2045.15
# 1994       1965.18

# %%
df2.to_csv("clean_data/sector.csv")

# %% [markdown]
# Finally, clean and inspect the spending vs life expectancy time csv. The csv uses aggregate indicators.

# %%
df3 = pd.read_csv("data/life_expect.csv")

# %%
df3.head(3)
# Out:
#           Country Name  1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  \
# 0             IDA only      53.039285      53.301928      53.582540
# 1  Lower middle income      59.513275      59.829442      60.183902
# 2  Low & middle income      63.106052      63.326673      63.493558
#
#    1993 [YR1993]  1994 [YR1994]  1995 [YR1995]  1996 [YR1996]  1997 [YR1997]  \
# 0      53.885894      54.209501      54.558191      54.930012      55.314159
# 1      60.514125      60.838366      61.157632      61.483625      61.817486
# 2      63.653089      63.868162      64.114060      64.404773      64.718892
#
#    1998 [YR1998]      ...        2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  \
# 0      55.710239      ...            59.858147      60.459556      61.044044
# 1      62.150271      ...            64.799075      65.165819      65.529030
# 2      65.011587      ...            67.538034      67.885040      68.212894
#
#    2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0      61.599662      62.116124      62.594243      63.040820      63.459617
# 1      65.901517      66.262475      66.596613      66.904789      67.193320
# 2      68.555213      68.865134      69.178624      69.459854      69.729661
#
#    2014 [YR2014]  2015 [YR2015]
# 0      63.853122      64.222994
# 1      67.458766      67.705178
# 2      69.970356      70.193261
#
# [3 rows x 27 columns]

# %%
df3.columns = ['aggregator','1990', '1991','1992', '1993', '1994', '1995', '1996', '1997', '1998','1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007','2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']

# %%
df3.head(3)
# Out:
#             aggregator       1990       1991       1992       1993       1994  \
# 0             IDA only  53.039285  53.301928  53.582540  53.885894  54.209501
# 1  Lower middle income  59.513275  59.829442  60.183902  60.514125  60.838366
# 2  Low & middle income  63.106052  63.326673  63.493558  63.653089  63.868162
#
#         1995       1996       1997       1998    ...           2006  \
# 0  54.558191  54.930012  55.314159  55.710239    ...      59.858147
# 1  61.157632  61.483625  61.817486  62.150271    ...      64.799075
# 2  64.114060  64.404773  64.718892  65.011587    ...      67.538034
#
#         2007       2008       2009       2010       2011       2012  \
# 0  60.459556  61.044044  61.599662  62.116124  62.594243  63.040820
# 1  65.165819  65.529030  65.901517  66.262475  66.596613  66.904789
# 2  67.885040  68.212894  68.555213  68.865134  69.178624  69.459854
#
#         2013       2014       2015
# 0  63.459617  63.853122  64.222994
# 1  67.193320  67.458766  67.705178
# 2  69.729661  69.970356  70.193261
#
# [3 rows x 27 columns]

# %%
df3 = df3.set_index('aggregator')

# %%
df3.head()
# Out:
#                           1990       1991       1992       1993       1994  \
# aggregator
# IDA only             53.039285  53.301928  53.582540  53.885894  54.209501
# Lower middle income  59.513275  59.829442  60.183902  60.514125  60.838366
# Low & middle income  63.106052  63.326673  63.493558  63.653089  63.868162
#
#                           1995       1996       1997       1998       1999  \
# aggregator
# IDA only             54.558191  54.930012  55.314159  55.710239  56.128856
# Lower middle income  61.157632  61.483625  61.817486  62.150271  62.469101
# Low & middle income  64.114060  64.404773  64.718892  65.011587  65.281524
#
#                        ...           2006       2007       2008       2009  \
# aggregator             ...
# IDA only               ...      59.858147  60.459556  61.044044  61.599662
# Lower middle income    ...      64.799075  65.165819  65.529030  65.901517
# Low & middle income    ...      67.538034  67.885040  68.212894  68.555213
#
#                           2010       2011       2012       2013       2014  \
# aggregator
# IDA only             62.116124  62.594243  63.040820  63.459617  63.853122
# Lower middle income  66.262475  66.596613  66.904789  67.193320  67.458766
# Low & middle income  68.865134  69.178624  69.459854  69.729661  69.970356
#
#                           2015
# aggregator
# IDA only             64.222994
# Lower middle income  67.705178
# Low & middle income  70.193261
#
# [3 rows x 26 columns]

# %%
df2_temp = pd.read_csv('data/aid_spending_by_sector_per_yer.csv')
df2_temp = df2_temp.set_index(['Sector(s)'])

# %%
df2_temp = df2_temp.drop(['Time Period'], axis=1)

# %%
dd = df2_temp.loc["I.2. Health, Total", :'2015']

# %%
df3 = df3.append(dd)

# %%
df3 = df3.T

# %%
df3.index.name = 'year'
df3.columns = ['ida_only', 'lower_middle_income', 'low_middle_income', 'health']

# %%
df3.head()
# Out:
#        ida_only  lower_middle_income  low_middle_income   health
# year
# 1990  53.039285            59.513275          63.106052  1613.27
# 1991  53.301928            59.829442          63.326673  1424.84
# 1992  53.582540            60.183902          63.493558  1617.43
# 1993  53.885894            60.514125          63.653089  1654.98
# 1994  54.209501            60.838366          63.868162  1831.49

# %%
df3.to_csv("clean_data/life_clean.csv")

# %%
df3.dtypes
# Out:
# ida_only               float64
# lower_middle_income    float64
# low_middle_income      float64
# health                 float64
# dtype: object
